# %%
import torch 
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch_geometric 
import torch_geometric.nn as gnn
from torch_geometric.loader import DataLoader as gDataLoader
from torch_geometric.data import Dataset as gDataset
from torch_geometric.data import Data
from torch_geometric.datasets import QM9
import rdkit
import os

# %%
def get_ei(smi) : 
    mol = rdkit.Chem.MolFromSmiles(smi) 
    n_atoms = mol.GetNumAtoms() 
    ei = []
    for bond in mol.GetBonds() :
        b = bond.GetBeginAtomIdx() 
        e = bond.GetEndAtomIdx() 
        ei.append([b,e])
    for bond in mol.GetBonds() :
        b = bond.GetBeginAtomIdx() 
        e = bond.GetEndAtomIdx() 
        ei.append([e, b])
    return torch.tensor(ei).T

def get_vocab(smi_list) :
    dic = {}
    for smi in smi_list :
        mol = rdkit.Chem.MolFromSmiles(smi) 
        for atom in mol.GetAtoms() : 
            symbol = atom.GetSymbol() 
            if symbol not in dic : 
                dic[symbol] = len(dic) 
    return dic 


def get_nf(smi, vocab) : 
    mol = rdkit.Chem.MolFromSmiles(smi) 
    atom_list = [vocab[atom.GetSymbol()] for atom in mol.GetAtoms()]
    return torch.tensor(atom_list)

# %%
class MyData(Data) : 
    def __cat_dim__(self, key, value, *args, **kwargs) : 
        if key == 'ei' :
            return None 
        return super().__cat_dim__(key, value, *args, **kwargs)

# %%
class MyDataset(gDataset) : 
    def __init__(self, root, filename, transform=None, pre_transform=None) : 
        self.filename = filename 
        super(MyDataset, self).__init__(root, transform, pre_transform)
        self.vocab = get_vocab(self.smi_list)
        
    @property 
    def raw_file_names(self) : 
        return self.filename
    
    @property
    def processed_file_names(self) : 
        with open(self.raw_paths[0], 'r') as f : 
            self.smi_list = f.readlines()
            self.smi_list = [s.strip() for s in self.smi_list]
        return [f'data_{i}.pt' for i in range(len(self.smi_list))]
    
    def download(self) : pass 

    def process(self) : 
        with open(self.raw_paths[0], 'r') as f : 
            self.smi_list = f.readlines()
            self.smi_list = [s.strip() for s in self.smi_list]
        self.vocab = get_vocab(self.smi_list) 
        ei = [get_ei(s) for s in self.smi_list] 
        nf = [get_nf(s, self.vocab) for s in self.smi_list] 
        
        for i, smi in enumerate(self.smi_list) : 
            data = MyData(x=nf[i],
                        edge_index=ei[i],
                        smi=smi,
                        ei=ei[i])
            torch.save(data, os.path.join(self.processed_dir, f'data_{i}.pt'))
    
    def len(self) : 
        return len(self.smi_list) 
    
    def get(self, idx) : 
        data = torch.load(os.path.join(self.processed_dir, f'data_{idx}.pt'))
        return data

# %%
dataset = MyDataset(root='data', filename=['25_MOSES_SMILES.txt'])
train_loader = gDataLoader(dataset, batch_size=64)
vocab = dataset.vocab
# Out:
# Processing...
# Done!

# %%
for i in train_loader :
    print(i.edge_index) 
    break
# Out:
# tensor([[  0,   1,   1,  ..., 872, 873, 865],
#         [  1,   2,   3,  ..., 871, 872, 872]])

# %%
embed = nn.Embedding(len(vocab), 500)

# %%
class GVAE(nn.Module) : 
    def __init__(self, d_model, d_latent) : 
        super(GVAE, self).__init__() 
        
        self.embedding = nn.Embedding(len(vocab), d_model)
        
        self.gcn1 = gnn.GCNConv(d_model, d_model) 
        self.gcn1_bn = nn.BatchNorm1d(d_model)
        
        self.nf_decode = nn.Linear(d_model, len(vocab)) 
        self.ei_decode = nn.Linear(d_model, 
        
    def get_z(self, mu, sigma) : 
        eps = torch.randn_like(sigma).to(mu.device) 
        z = mu + eps * torch.exp(sigma * 0.5) 
        return z 
    
    def forward(self, x) : 
        nf, ei, batch = x.x, x.edge_index, x.batch
        nf = self.embedding(nf) 
        
        nf = self.gcn1(nf, ei) 
        nf = F.relu(self.gc1_bn(nf)) 
        
        pool = gnn.global_add_pool(nf, batch)
